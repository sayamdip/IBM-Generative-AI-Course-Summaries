# %%
# Install the transformers library
# !pip install transformers pillow torch torchvision torchaudio
from transformers import BlipProcessor, BlipForConditionalGeneration
from PIL import Image

# Initialize the processor and model from Hugging Face
processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")

# Load an image
image = Image.open("Image.png")

# Prepare the image
inputs = processor(image, return_tensors="pt")

# Generate captions
outputs = model.generate(**inputs)
caption = processor.decode(outputs[0],skip_special_tokens=True)
 
print("Generated Caption:", caption)
# Out:
# Requirement already satisfied: transformers in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (5.14.1)
# Requirement already satisfied: pillow in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (12.2.0)
# Requirement already satisfied: torch in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (2.13.0)
# Requirement already satisfied: torchvision in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (0.28.0)
# Requirement already satisfied: torchaudio in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (2.11.0)
# Requirement already satisfied: huggingface-hub<2.0,>=1.5.0 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from transformers) (1.26.0)
# Requirement already satisfied: numpy>=1.17 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from transformers) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from transformers) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from transformers) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from transformers) (2026.7.19)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from transformers) (0.22.2)
# Requirement already satisfied: typer in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from transformers) (0.27.1)
# Requirement already satisfied: safetensors>=0.8.0 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from transformers) (0.8.0)
# Requirement already satisfied: tqdm>=4.60 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from transformers) (4.67.3)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (8.4.2)
# Requirement already satisfied: filelock>=3.10.0 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (3.32.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (2026.7.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.1 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (1.6.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (0.28.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from huggingface-hub<2.0,>=1.5.0->transformers) (4.15.0)
# Requirement already satisfied: anyio in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (4.13.0)
# Requirement already satisfied: certifi in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (1.0.9)
# Requirement already satisfied: idna in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (3.11)
# Requirement already satisfied: h11>=0.16 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub<2.0,>=1.5.0->transformers) (0.16.0)
# Requirement already satisfied: setuptools>=77.0.3 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from torch) (82.0.1)
# Requirement already satisfied: sympy>=1.13.3 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from torch) (3.1.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from jinja2->torch) (3.0.3)
# Requirement already satisfied: shellingham>=1.3.0 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from typer->transformers) (1.5.4)
# Requirement already satisfied: rich>=13.8.0 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from typer->transformers) (15.0.0)
# Requirement already satisfied: annotated-doc>=0.0.2 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from typer->transformers) (0.0.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from rich>=13.8.0->typer->transformers) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from rich>=13.8.0->typer->transformers) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from markdown-it-py>=2.2.0->rich>=13.8.0->typer->transformers) (0.1.2)
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Generated Caption: a cat sitting on a wall looking at the camera

# %%
from transformers import BlipProcessor, BlipForConditionalGeneration
from PIL import Image

# Initialize the processor and model from Hugging Face
processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")

# Load an image
image = Image.open("Tiger.png")

# Prepare the image
inputs = processor(image, return_tensors="pt")

# Generate captions
outputs = model.generate(**inputs)
caption = processor.decode(outputs[0],skip_special_tokens=True)
 
print("Generated Caption:", caption)
# Out:
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Generated Caption: a tiger with a big face

# %%
from transformers import BlipProcessor, BlipForConditionalGeneration
from PIL import Image

# Initialize the processor and model from Hugging Face
processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-base")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-base")

# Load an image
image2 = Image.open("Image2.png")

# Prepare the image
inputs = processor(image2, return_tensors="pt")

# Generate captions
outputs = model.generate(**inputs)
caption = processor.decode(outputs[0],skip_special_tokens=True)
 
print("Generated Caption:", caption)
# Out:
# Loading weights:   0%|          | 0/473 [00:00<?, ?it/s]
# Generated Caption: the new volvo suv is shown in a screenshote

# %% [markdown]
# # Visual Question Answering

# %% [markdown]
# ### 1) Using BLIP Image Captioning Model

# %%
# Import required modules
import requests
from PIL import Image
from transformers import BlipProcessor, BlipForConditionalGeneration

# Load BLIP processor and model (captioning model — treats the "question" as a caption prefix ) 
processor = BlipProcessor.from_pretrained("Salesforce/blip-image-captioning-large")
model = BlipForConditionalGeneration.from_pretrained("Salesforce/blip-image-captioning-large")

# Load image from URL
img_url = "https://storage.googleapis.com/sfr-vision-language-research/BLIP/demo.jpg"
image = Image.open(requests.get(img_url, stream=True).raw).convert("RGB")

# Define question about the image
question = "What is in the image?"

# Prepare both image + question as input
inputs = processor(image, question, return_tensors="pt")

# Generate answer
outputs = model.generate(**inputs)

# Decode output into readable text
answer = processor.decode(outputs[0], skip_special_tokens=True)

# Print final answer
print("Answer:", answer)
# Out:
# Loading weights:   0%|          | 0/616 [00:00<?, ?it/s]
# Answer: what is in the image? a woman and her dog on the beach

# %% [markdown]
# ### 2) Using BLIP VQA Model

# %%
# Import required modules
import requests
from PIL import Image
from transformers import BlipProcessor, BlipForQuestionAnswering

# Load the BLIP VQA processor and model
processor = BlipProcessor.from_pretrained("Salesforce/blip-vqa-base")
model = BlipForQuestionAnswering.from_pretrained("Salesforce/blip-vqa-base")


# Load image from URL
img_url = "https://upload.wikimedia.org/wikipedia/commons/thumb/d/d0/Felis_silvestris_silvestris_Luc_Viatour.jpg/960px-Felis_silvestris_silvestris_Luc_Viatour.jpg?utm_source=en.wikipedia.org&utm_campaign=imageinfo&utm_content=thumbnail"

# Add a User-Agent header so Wikipedia doesn't block the request
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64)"}
image = Image.open(requests.get(img_url, headers=headers, stream=True).raw).convert("RGB")

# Define a question about the image
question = "What animal is shown in the image?"

# Prepare the inputs
inputs = processor(image, question, return_tensors="pt")

# Generate the answer
outputs = model.generate(**inputs)

# Decode the output
answer = processor.decode(outputs[0], skip_special_tokens=True)

print("Answer:", answer)
# Out:
# Task was destroyed but it is pending!
# task: <Task pending name='Task-114' coro=<_async_in_context.<locals>.run_in_context() done, defined at /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages/ipykernel/utils.py:57> wait_for=<Task pending name='Task-115' coro=<Kernel.shell_main() running at /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages/ipykernel/kernelbase.py:597> cb=[Task.task_wakeup()]> cb=[ZMQStream._run_callback.<locals>._log_error() at /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages/zmq/eventloop/zmqstream.py:563]>
# /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages/h11/_headers.py:249: RuntimeWarning: coroutine 'Kernel.shell_main' was never awaited
#   for found_split_value in found_raw_value.split(b","):
# RuntimeWarning: Enable tracemalloc to get the object allocation traceback
# Task was destroyed but it is pending!
# task: <Task pending name='Task-115' coro=<Kernel.shell_main() running at /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages/ipykernel/kernelbase.py:597> cb=[Task.task_wakeup()]>
# Loading weights:   0%|          | 0/788 [00:00<?, ?it/s]
# /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages/transformers/generation/utils.py:1638: UserWarning: Using the model-agnostic default `max_length` (=21) to control the generation length. We recommend setting `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# Answer: cat
