# %% [markdown]
# ## Conditions Statement

# %%
age=17
if(age>18):
    print("You Can Enter")
print("Move On")
# Out:
# Move On

# %%
age=17
if(age>18):
    print("You Can Enter")
else:
    print("You Can Go See Meat Loaf Concert")
print("Move On")
# Out:
# You Can Go See Meat Loaf Concert
# Move On

# %%
age=18
if(age>18):
    print("You Can Enter")
elif(age==18):
    print("Go See Pink Floyd")
else:
    print("Go See Meat Loaf Concert")
print("Move On")
# Out:
# Go See Pink Floyd
# Move On

# %% [markdown]
# ## Logical Operators

# %%
## Use Of or Operator
album_year=1990
if((album_year<1980) or(album_year>1989)):
    print("The Album Was Made In The 70's Or 90's")
else:
    print("The Album Was Made In The 1980's")
# Out:
# The Album Was Made In The 70's Or 90's

# %%
## Use Of and Operator
album_year=1983
if((album_year>1979) and (album_year<1990)):
    print("This Album Was Made In The 80's")
# Out:
# This Album Was Made In The 80's

# %%
## Real Life Example
user_choice=input("Enter A Choice= ")
if(user_choice=="Withdraw Cash"):
    amount=int(input("Enter Your Amount= "))
    if(amount%10==0):
        print("Amount Dispensed: ",amount)
    else:
        print("Please Enter A Multiple Of 10.")
else:
    print("Thank You For Using The ATM.")
# Out:
# Enter A Choice=  Withdraw Cash
# Enter Your Amount=  400
# Amount Dispensed:  400
