# %%
a=40
b=50
print(a+b)
# Out:
# 90

# %%
print("Hello World")
# Out:
# Hello World

# %%
a=int(input("Enter Number 1= "))
b=int(input("Enter Number 2= "))
c=a*b
print(c)
# Out:
# Enter Number 1=  90
# Enter Number 2=  89
# 8010
