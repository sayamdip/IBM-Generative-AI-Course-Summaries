# %% [markdown]
# ## This Is The First Code

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# ## Create A Line Plot
# This Shows How To Create A Line Plot

# %%
import matplotlib.pyplot as plt
a=[1,2,3,4]
b=[-1,-2,-3,-4]
plt.plot(a,b)
plt.show()

# %% [markdown]
# ## Check The Version Of Python Using

# %%
import sys
print(sys.version)
# Out:
# 3.11.15 (main, Mar 11 2026, 17:14:47) [Clang 20.1.8 ]

# %% [markdown]
# ## Comments In Python

# %%
print("Hello World!") # This Line Prints A String
