# %% [markdown]
# ### APIs

# %%
# !pip install pycoingecko
from pycoingecko import CoinGeckoAPI
# Out:
# Requirement already satisfied: pycoingecko in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (3.2.0)
# Requirement already satisfied: requests in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from pycoingecko) (2.33.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from requests->pycoingecko) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from requests->pycoingecko) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from requests->pycoingecko) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from requests->pycoingecko) (2026.2.25)

# %%
cg=CoinGeckoAPI()
bitcoin_data=cg.get_coin_market_chart_by_id(id="bitcoin",vs_currency="usd",days=30)
print(bitcoin_data)
# Out:
# {'prices': [[1776348031437, 73705.01360985098], [1776351628941, 73938.04397589041], [1776355218900, 74740.25080601992], [1776358848233, 74214.42990809566], [1776362426081, 74273.00358424732], [1776366040853, 75017.42674367223], [1776369623094, 75389.68135904678], [1776373242253, 75240.31590673576], [1776376827315, 74944.91566812144], [1776380458176, 74883.21300083205], [1776384030955, 75149.1930221427], [1776387653697, 74977.75409490333], [1776391222764, 74787.851905865], [1776394807573, 74695.48255658832], [1776398432051, 74649.52985426539], [1776402060216, 74792.21540789708], [1776405653685, 74666.08972542649], [1776409248343, 74913.00922361523], [1776412817378, 75044.90134871528], [1776416471858, 75739.35058143485], [1776420035344, 75797.67899200699], [1776423613677, 75297.00919396247], [1776427227085, 75589.10032806055], [1776430804590, 76213.45555656118], [1776434480758, 77361.36237765808], [1776438058285, 77956.91427499668], [1776441669527, 77828.185699857], [1776445275036, 77862.89905005145], [1776448831603, 77498.81630549654], [1776452452485, 77164.03670386429], [1776456054342, 77436.59527540709], [1776459640617, 77362.87288021417], [1776463262842, 77496.71066229149], [1776466869578, 77308.43885337995], [1776470415387, 77128.44334858148], [1776474028704, 77169.64712633878], [1776477612377, 77201.78314338902], [1776481253738, 77315.4096324451], [1776484838295, 77013.53238285403], [1776488451751, 77158.48113774008], [1776492024127, 77152.68049883858], [1776495636584, 77131.3006381946], [1776499225517, 76998.06796704927], [1776502839772, 76755.0998125113], [1776506408049, 76617.80623429554], [1776510045450, 76188.45755869409], [1776513657316, 76072.68979550186], [1776517263736, 76224.9598173141], [1776520825301, 76137.19860160364], [1776524426751, 76251.58670751007], [1776528012360, 76181.98651177097], [1776531647226, 75927.57132288165], [1776535253230, 75864.95221180288], [1776538809275, 75653.54136303878], [1776542456722, 75670.66377392902], [1776546030982, 75757.95160113281], [1776549620269, 75828.32687513834], [1776553247003, 75830.19171188552], [1776556819243, 75728.45681761758], [1776560455762, 75652.21984514158], [1776564038652, 75642.12663561944], [1776567677341, 75558.77945979389], [1776571274063, 75540.50887836353], [1776574835911, 75681.49533537882], [1776578435261, 75569.83917977821], [1776582067182, 75407.80704076507], [1776585633524, 75295.98459973742], [1776589204218, 75244.24719211207], [1776592859248, 75020.97270538584], [1776596455940, 75236.36654292562], [1776600037294, 75599.26577131222], [1776603641851, 75624.6529610848], [1776607228888, 75920.89178630568], [1776610803231, 76024.76202757412], [1776614420279, 75840.65451654213], [1776618018075, 75495.36817299578], [1776621636729, 74800.94102146984], [1776625255283, 74795.1465182244], [1776628843659, 74974.34476516958], [1776632446413, 74689.24400809643], [1776636018388, 74460.14184607656], [1776639679302, 74137.21873636951], [1776643248126, 73856.05501487634], [1776646850777, 74346.05375810764], [1776650444180, 74623.05265769569], [1776654004643, 74458.21813860718], [1776657622245, 74653.54610763465], [1776661238550, 74581.28237935815], [1776664852141, 74277.51462154883], [1776668432318, 74789.56984853405], [1776672052000, 74795.97600729625], [1776675613386, 74741.97729093608], [1776679246167, 75062.12403807922], [1776682847491, 75045.02524645194], [1776686430682, 75179.56431310959], [1776690046403, 75285.69738107114], [1776693621627, 75290.96918392694], [1776697264999, 75004.42275652137], [1776700811000, 75687.721421251], [1776704431977, 75340.28666497084], [1776708026267, 75921.15197965335], [1776711659005, 76437.62877231697], [1776715240654, 76314.88533036472], [1776718882441, 76302.84677235561], [1776722442504, 75970.00268011336], [1776726009650, 75992.70086029985], [1776729634491, 75874.54629352967], [1776733242456, 76085.88237404238], [1776736856297, 75921.29817954023], [1776740455464, 75628.03723799669], [1776744058013, 75728.13586903199], [1776 ...

# %%
print(bitcoin_data["prices"])
# Out:
# [[1776348031437, 73705.01360985098], [1776351628941, 73938.04397589041], [1776355218900, 74740.25080601992], [1776358848233, 74214.42990809566], [1776362426081, 74273.00358424732], [1776366040853, 75017.42674367223], [1776369623094, 75389.68135904678], [1776373242253, 75240.31590673576], [1776376827315, 74944.91566812144], [1776380458176, 74883.21300083205], [1776384030955, 75149.1930221427], [1776387653697, 74977.75409490333], [1776391222764, 74787.851905865], [1776394807573, 74695.48255658832], [1776398432051, 74649.52985426539], [1776402060216, 74792.21540789708], [1776405653685, 74666.08972542649], [1776409248343, 74913.00922361523], [1776412817378, 75044.90134871528], [1776416471858, 75739.35058143485], [1776420035344, 75797.67899200699], [1776423613677, 75297.00919396247], [1776427227085, 75589.10032806055], [1776430804590, 76213.45555656118], [1776434480758, 77361.36237765808], [1776438058285, 77956.91427499668], [1776441669527, 77828.185699857], [1776445275036, 77862.89905005145], [1776448831603, 77498.81630549654], [1776452452485, 77164.03670386429], [1776456054342, 77436.59527540709], [1776459640617, 77362.87288021417], [1776463262842, 77496.71066229149], [1776466869578, 77308.43885337995], [1776470415387, 77128.44334858148], [1776474028704, 77169.64712633878], [1776477612377, 77201.78314338902], [1776481253738, 77315.4096324451], [1776484838295, 77013.53238285403], [1776488451751, 77158.48113774008], [1776492024127, 77152.68049883858], [1776495636584, 77131.3006381946], [1776499225517, 76998.06796704927], [1776502839772, 76755.0998125113], [1776506408049, 76617.80623429554], [1776510045450, 76188.45755869409], [1776513657316, 76072.68979550186], [1776517263736, 76224.9598173141], [1776520825301, 76137.19860160364], [1776524426751, 76251.58670751007], [1776528012360, 76181.98651177097], [1776531647226, 75927.57132288165], [1776535253230, 75864.95221180288], [1776538809275, 75653.54136303878], [1776542456722, 75670.66377392902], [1776546030982, 75757.95160113281], [1776549620269, 75828.32687513834], [1776553247003, 75830.19171188552], [1776556819243, 75728.45681761758], [1776560455762, 75652.21984514158], [1776564038652, 75642.12663561944], [1776567677341, 75558.77945979389], [1776571274063, 75540.50887836353], [1776574835911, 75681.49533537882], [1776578435261, 75569.83917977821], [1776582067182, 75407.80704076507], [1776585633524, 75295.98459973742], [1776589204218, 75244.24719211207], [1776592859248, 75020.97270538584], [1776596455940, 75236.36654292562], [1776600037294, 75599.26577131222], [1776603641851, 75624.6529610848], [1776607228888, 75920.89178630568], [1776610803231, 76024.76202757412], [1776614420279, 75840.65451654213], [1776618018075, 75495.36817299578], [1776621636729, 74800.94102146984], [1776625255283, 74795.1465182244], [1776628843659, 74974.34476516958], [1776632446413, 74689.24400809643], [1776636018388, 74460.14184607656], [1776639679302, 74137.21873636951], [1776643248126, 73856.05501487634], [1776646850777, 74346.05375810764], [1776650444180, 74623.05265769569], [1776654004643, 74458.21813860718], [1776657622245, 74653.54610763465], [1776661238550, 74581.28237935815], [1776664852141, 74277.51462154883], [1776668432318, 74789.56984853405], [1776672052000, 74795.97600729625], [1776675613386, 74741.97729093608], [1776679246167, 75062.12403807922], [1776682847491, 75045.02524645194], [1776686430682, 75179.56431310959], [1776690046403, 75285.69738107114], [1776693621627, 75290.96918392694], [1776697264999, 75004.42275652137], [1776700811000, 75687.721421251], [1776704431977, 75340.28666497084], [1776708026267, 75921.15197965335], [1776711659005, 76437.62877231697], [1776715240654, 76314.88533036472], [1776718882441, 76302.84677235561], [1776722442504, 75970.00268011336], [1776726009650, 75992.70086029985], [1776729634491, 75874.54629352967], [1776733242456, 76085.88237404238], [1776736856297, 75921.29817954023], [1776740455464, 75628.03723799669], [1776744058013, 75728.13586903199], [1776747632588,  ...

# %%
import pandas as pd
data=pd.DataFrame(bitcoin_data["prices"],columns=["TimeStamp","Price"])
print(data)
# Out:
#          TimeStamp         Price
# 0    1776348031437  73705.013610
# 1    1776351628941  73938.043976
# 2    1776355218900  74740.250806
# 3    1776358848233  74214.429908
# 4    1776362426081  74273.003584
# ..             ...           ...
# 716  1778925660182  78054.510708
# 717  1778929233785  77912.516783
# 718  1778932840423  78051.937282
# 719  1778936425024  77982.286288
# 720  1778941363000  77897.346868
#
# [721 rows x 2 columns]

# %%
data["Date"]=pd.to_datetime(data["TimeStamp"],unit="ms")
print(data["Date"])
# Out:
# 0     2026-04-16 14:00:31.437
# 1     2026-04-16 15:00:28.941
# 2     2026-04-16 16:00:18.900
# 3     2026-04-16 17:00:48.233
# 4     2026-04-16 18:00:26.081
#                 ...
# 716   2026-05-16 10:01:00.182
# 717   2026-05-16 11:00:33.785
# 718   2026-05-16 12:00:40.423
# 719   2026-05-16 13:00:25.024
# 720   2026-05-16 14:22:43.000
# Name: Date, Length: 721, dtype: datetime64[ms]

# %%
data["Date"].head()
# Out:
# 0   2026-04-16 14:00:31.437
# 1   2026-04-16 15:00:28.941
# 2   2026-04-16 16:00:18.900
# 3   2026-04-16 17:00:48.233
# 4   2026-04-16 18:00:26.081
# Name: Date, dtype: datetime64[ms]

# %%
candlestick_data=data.groupby(data.Date.dt.date).agg({"Price":["min","max","first","last"]})
print(candlestick_data)
# Out:
#                    Price
#                      min           max         first          last
# Date
# 2026-04-16  73705.013610  75389.681359  73705.013610  74883.213001
# 2026-04-17  74649.529854  77956.914275  75149.193022  77308.438853
# 2026-04-18  75653.541363  77315.409632  77128.443349  75830.191712
# 2026-04-19  74137.218736  76024.762028  75728.456818  74137.218736
# 2026-04-20  73856.055015  76437.628772  73856.055015  75992.700860
# 2026-04-21  74995.377829  76784.394177  75874.546294  75629.089683
# 2026-04-22  76308.729330  79321.159684  76350.252029  78602.897314
# 2026-04-23  77421.706969  78406.293044  78194.783349  78241.974341
# 2026-04-24  77360.724758  78450.365400  78260.619980  77360.724758
# 2026-04-25  77268.594685  77798.770530  77444.795637  77571.924691
# 2026-04-26  77421.968060  78407.161255  77619.142199  78378.050613
# 2026-04-27  76597.376292  79260.262487  78645.125602  77068.292465
# 2026-04-28  75849.311787  77383.540579  77361.299110  76229.403850
# 2026-04-29  75436.565811  77629.866909  76345.225210  75907.299510
# 2026-04-30  75459.652655  76465.472689  75774.885523  76189.372056
# 2026-05-01  76286.577110  78695.213558  76286.577110  78138.269761
# 2026-05-02  78128.460243  78804.995364  78172.074221  78804.995364
# 2026-05-03  78146.922238  79164.912627  78666.020563  79164.912627
# 2026-05-04  78523.092095  80468.077518  78542.808037  80060.107055
# 2026-05-05  79824.403312  81640.766068  79824.403312  81102.490556
# 2026-05-06  80925.093655  82496.208207  80925.093655  81341.728243
# 2026-05-07  79778.971014  81497.729069  81424.995157  79903.133157
# 2026-05-08  79467.277699  80272.107552  80022.041250  80272.107552
# 2026-05-09  80189.065036  80894.730129  80189.065036  80742.816774
# 2026-05-10  80636.174386  82025.589323  80678.033943  82025.589323
# 2026-05-11  80694.979325  82145.656068  82145.656068  81823.286175
# 2026-05-12  79962.923884  81725.207717  81725.207717  80652.284345
# 2026-05-13  78827.547922  81234.864127  80480.886001  79401.913320
# 2026-05-14  78973.186317  81700.160591  79277.804518  81418.220209
# 2026-05-15  78742.811979  81487.622792  81051.982888  79067.663781
# 2026-05-16  77897.346868  79124.943246  79071.540267  77897.346868

# %%
candlestick_data.head()
# Out:
#                    Price
#                      min           max         first          last
# Date
# 2026-04-16  73705.013610  75389.681359  73705.013610  74883.213001
# 2026-04-17  74649.529854  77956.914275  75149.193022  77308.438853
# 2026-04-18  75653.541363  77315.409632  77128.443349  75830.191712
# 2026-04-19  74137.218736  76024.762028  75728.456818  74137.218736
# 2026-04-20  73856.055015  76437.628772  73856.055015  75992.700860

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
dict_={"a":[11,21,31],"b":[12,22,32]}
df=pd.DataFrame(dict_)
type(df)
# Out:
# pandas.DataFrame

# %%
df.head()
# Out:
#     a   b
# 0  11  12
# 1  21  22
# 2  31  32

# %%
df.mean()
# Out:
# a    21.0
# b    22.0
# dtype: float64

# %% [markdown]
# ### REST APIs
# Rest APIs function by sending a request, the request is communicated via HTTP message. The HTTP message usually contains a JSON file. This contains instructions for what operation we would like the service or resource to perform. In a similar manner, API returns a response, via an HTTP message, this response is usually contained within a JSON.

# %% [markdown]
# ### NBA API

# %%
# !pip install nba_api
# Out:
# Collecting nba_api
#   Downloading nba_api-1.11.4-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: numpy>=1.26.0 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from nba_api) (2.4.4)
# Requirement already satisfied: pandas>=2.1.0 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from nba_api) (3.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.32.3 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from nba_api) (2.33.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.3->nba_api) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.3->nba_api) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.3->nba_api) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from requests<3.0.0,>=2.32.3->nba_api) (2026.2.25)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from pandas>=2.1.0->nba_api) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=2.1.0->nba_api) (1.17.0)
# Downloading nba_api-1.11.4-py3-none-any.whl (322 kB)
# Installing collected packages: nba_api
# Successfully installed nba_api-1.11.4

# %%
from nba_api.stats.static import teams

# %%
def one_dict(list_dict):
    keys=list_dict[0].keys()
    out_dict={key:[] for key in keys}
    for dict_ in list_dict:
        for key,value in dict_.items():
            out_dict[key].append(value)
    return out_dict

# %%
nba_teams=teams.get_teams()
nba_teams[0:]
# Out:
# [{'id': 1610612737,
#   'full_name': 'Atlanta Hawks',
#   'abbreviation': 'ATL',
#   'nickname': 'Hawks',
#   'city': 'Atlanta',
#   'state': 'Georgia',
#   'year_founded': 1949},
#  {'id': 1610612738,
#   'full_name': 'Boston Celtics',
#   'abbreviation': 'BOS',
#   'nickname': 'Celtics',
#   'city': 'Boston',
#   'state': 'Massachusetts',
#   'year_founded': 1946},
#  {'id': 1610612739,
#   'full_name': 'Cleveland Cavaliers',
#   'abbreviation': 'CLE',
#   'nickname': 'Cavaliers',
#   'city': 'Cleveland',
#   'state': 'Ohio',
#   'year_founded': 1970},
#  {'id': 1610612740,
#   'full_name': 'New Orleans Pelicans',
#   'abbreviation': 'NOP',
#   'nickname': 'Pelicans',
#   'city': 'New Orleans',
#   'state': 'Louisiana',
#   'year_founded': 2002},
#  {'id': 1610612741,
#   'full_name': 'Chicago Bulls',
#   'abbreviation': 'CHI',
#   'nickname': 'Bulls',
#   'city': 'Chicago',
#   'state': 'Illinois',
#   'year_founded': 1966},
#  {'id': 1610612742,
#   'full_name': 'Dallas Mavericks',
#   'abbreviation': 'DAL',
#   'nickname': 'Mavericks',
#   'city': 'Dallas',
#   'state': 'Texas',
#   'year_founded': 1980},
#  {'id': 1610612743,
#   'full_name': 'Denver Nuggets',
#   'abbreviation': 'DEN',
#   'nickname': 'Nuggets',
#   'city': 'Denver',
#   'state': 'Colorado',
#   'year_founded': 1976},
#  {'id': 1610612744,
#   'full_name': 'Golden State Warriors',
#   'abbreviation': 'GSW',
#   'nickname': 'Warriors',
#   'city': 'San Francisco',
#   'state': 'California',
#   'year_founded': 1946},
#  {'id': 1610612745,
#   'full_name': 'Houston Rockets',
#   'abbreviation': 'HOU',
#   'nickname': 'Rockets',
#   'city': 'Houston',
#   'state': 'Texas',
#   'year_founded': 1967},
#  {'id': 1610612746,
#   'full_name': 'Los Angeles Clippers',
#   'abbreviation': 'LAC',
#   'nickname': 'Clippers',
#   'city': 'Los Angeles',
#   'state': 'California',
#   'year_founded': 1970},
#  {'id': 1610612747,
#   'full_name': 'Los Angeles Lakers',
#   'abbreviation': 'LAL',
#   'nickname': 'Lakers',
#   'city': 'Los Angeles',
#   'state': 'California',
#   'year_founded': 1948},
#  {'id': 1610612748,
#   'full_name': 'Miami Heat',
#   'abbreviation': 'MIA',
#   'nickname': 'Heat',
#   'city': 'Miami',
#   'state': 'Florida',
#   'year_founded': 1988},
#  {'id': 1610612749,
#   'full_name': 'Milwaukee Bucks',
#   'abbreviation': 'MIL',
#   'nickname': 'Bucks',
#   'city': 'Milwaukee',
#   'state': 'Wisconsin',
#   'year_founded': 1968},
#  {'id': 1610612750,
#   'full_name': 'Minnesota Timberwolves',
#   'abbreviation': 'MIN',
#   'nickname': 'Timberwolves',
#   'city': 'Minnesota',
#   'state': 'Minnesota',
#   'year_founded': 1989},
#  {'id': 1610612751,
#   'full_name': 'Brooklyn Nets',
#   'abbreviation': 'BKN',
#   'nickname': 'Nets',
#   'city': 'Brooklyn',
#   'state': 'New York',
#   'year_founded': 1976},
#  {'id': 1610612752,
#   'full_name': 'New York Knicks',
#   'abbreviation': 'NYK',
#   'nickname': 'Knicks',
#   'city': 'New York',
#   'state': 'New York',
#   'year_founded': 1946},
#  {'id': 1610612753,
#   'full_name': 'Orlando Magic',
#   'abbreviation': 'ORL',
#   'nickname': 'Magic',
#   'city': 'Orlando',
#   'state': 'Florida',
#   'year_founded': 1989},
#  {'id': 1610612754,
#   'full_name': 'Indiana Pacers',
#   'abbreviation': 'IND',
#   'nickname': 'Pacers',
#   'city': 'Indiana',
#   'state': 'Indiana',
#   'year_founded': 1976},
#  {'id': 1610612755,
#   'full_name': 'Philadelphia 76ers',
#   'abbreviation': 'PHI',
#   'nickname': '76ers',
#   'city': 'Philadelphia',
#   'state': 'Pennsylvania',
#   'year_founded': 1949},
#  {'id': 1610612756,
#   'full_name': 'Phoenix Suns',
#   'abbreviation': 'PHX',
#   'nickname': 'Suns',
#   'city': 'Phoenix',
#   'state': 'Arizona',
#   'year_founded': 1968},
#  {'id': 1610612757,
#   'full_name': 'Portland Trail Blazers',
#   'abbreviation': 'POR',
#   'nickname': 'Trail Blazers',
#   'city': 'Portland',
#   'state': 'Oregon',
#   'year_founded': 1970},
#  {'id': 1610612758,
#   'full_name': 'Sacramento Kings',
#   'abbreviation': 'SAC',
#   'nickname': 'Kings',
#   'city': 'Sacramento',
#   'state': 'California',
#   'year_founded': 1948},
#  {'id': 1610612759,
#   'full_name': 'San Antonio Spurs',
#   'abbreviation': 'SAS',
#   'nickname': 'Spurs',
#   'city': 'San Antonio',
#   'state': 'Texas',
#   'year_founded': 1976},
#  {'id': 1610612760,
#   'full_name': 'Oklahoma City Thunder',
#   'abbreviation': 'OKC',
#   'nickname': 'Thunder',
#   'city': 'Oklahoma City',
#   'state': 'Oklahoma',
#   'year_founded': 1967},
#  {'id': 1610612761,
#   'full_name': 'Toronto Raptors',
#   'abbreviation': 'TOR',
#   'nickname': 'Raptors',
#   'city': 'Toronto',
#   'state': 'Ontario',
#   'year_founded': 1995},
#  {'id': 1610612762,
#   'full_name': 'Utah Jazz',
#   'abbreviation': 'UTA',
#   'nickname': 'Jazz',
#   'city': 'Utah',
#   'state': 'Utah',
#   'year_founded': 1974},
#  {'id': 1610612763,
#   'full_name': 'Memphis Grizzlies',
#   'abbreviation': 'MEM',
#   'nickname': 'Grizzlies',
#   'city': 'Memphis',
#   'state': 'Tennessee',
#   'year_founded': 1995},
#  {'id': 1610612764,
#   'full_name': 'Washington Wizards',
#   'abbreviation': 'WAS',
#   'nickname': 'Wizards',
#   'city': 'Washington',
#   'state': 'District of Columbia',
#   'year_founded': 1961},
#  {'id': 1610612765,
#   'full_name': 'Detroit Pistons',
#   'abbreviation': 'DET',
#   'nickname': 'Pistons',
#   'city': 'Detroit',
#   'state': 'Michigan',
#   'year_founded': 1948},
#  {'id': 1610612766,
#   'full_name': 'Charlotte Hornets',
#   'abbreviation': 'CHA',
#   'nickname': 'Hornets',
#   'city': 'Charlotte',
#   'state': 'North Carolina',
#   'year_founded': 1988}]

# %% [markdown]
# dict_nba_team=one_dict(nba_teams)
# df_teams=pd.DataFrame(dict_nba_team)
# df_teams.head()

# %%
df_warriors=df_teams[df_teams["nickname"]]="Warriors"
df_warriors
# Out:
# 'Warriors'

# %% [markdown]
# ### Requests

# %%
import requests
url="https://www.ibm.com/"
r=requests.get(url)
r.status_code
header=r.headers
print(header["date"])
print(header["Content-Type"])
print(r.encoding)
print(r.text[0:100])
# Out:
# Fri, 22 May 2026 06:39:59 GMT
# text/html;charset=utf-8
# utf-8
#
# <!DOCTYPE HTML>
#
# <html lang="en">
# <head>

# %% [markdown]
# ### GET Request

# %%
url_get="http://httpbin.org/get"
payload={"name":"Joseph","ID":"123"}
r=requests.get(url_get,params=payload)
r.url:"http://httpbin.org/get?name=Joseph&ID=123"
r.status_code
r.text
r.json()
r.json()["args"]
# Out:
# {'ID': '123', 'name': 'Joseph'}

# %% [markdown]
# ### POST

# %%
url_post="http://httpbin.org/post"
payload={"name":"Joseph","ID":"123"}
r_post=requests.post(url_post,data=payload)
print("POST request URL:",r_post.url)
print("GET request URL:",r.url)
# Out:
# POST request URL: http://httpbin.org/post
# GET request URL: http://httpbin.org/get?name=Joseph&ID=123

# %% [markdown]
# ### Web Scrapping

# %%
pip install beautifulsoup4
# Out:
# Requirement already satisfied: beautifulsoup4 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (4.14.3)
# Requirement already satisfied: soupsieve>=1.6.1 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from beautifulsoup4) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from beautifulsoup4) (4.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install requests
# Out:
# Requirement already satisfied: requests in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (2.33.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from requests) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.26 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from requests) (2.6.3)
# Requirement already satisfied: certifi>=2023.5.7 in /Users/sayamdipdeychaklader/.conda/envs/myenv/lib/python3.11/site-packages (from requests) (2026.2.25)
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup
print("Beautiful Soup Installed")

import requests
print("Requests Installed")
# Out:
# Beautiful Soup Installed
# Requests Installed

# %%
import requests
from bs4 import BeautifulSoup
url="https://en.wikipedia.org/wiki/IBM"
response=requests.get(url)
html_content=response.text
soup=BeautifulSoup(html_content,"html.parser")
print(html_content[:500])
# Out:
# Please set a user-agent and respect our robot policy https://w.wiki/4wJS. See also https://phabricator.wikimedia.org/T400119.

# %%
# Find all <a> tags (anchor tags) in the HTML
links=soup.find_all("a")

# Iterate through the list of links and print their text
for link in links:
    print(link.text)

# %% [markdown]
# ### Random User And Fruityvice API Examples
# RandomUser is an open-source, free API providing developers with randomly generated users to be used as placeholders for testing purposes. This makes the tool similar to Lorem Ipsum, but is a placeholder for people instead of text. The API can return multiple results, as well as specify generated user details such as gender, email, image, username, address, title, first and last name, and more. More information on RandomUser can be found here.
#
# The Fruityvice API web service which provides data for all kinds of fruit! You can use Fruityvice to find out interesting information about fruit and educate yourself. The web service is completely free to use and contribute to.

# %%
# !pip install randomuser
# Out:
# Collecting randomuser
#   Downloading randomuser-1.6.tar.gz (5.0 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: randomuser
#   Building wheel for randomuser (pyproject.toml) ... done
#   Created wheel for randomuser: filename=randomuser-1.6-py3-none-any.whl size=5105 sha256=4254721af0c1363da5404a6c150a486e788e43ef0845c39f40b7dfaa6a689c18
#   Stored in directory: /Users/sayamdipdeychaklader/Library/Caches/pip/wheels/fc/8d/74/bcdd5e8a9433bfa4c4f9c1cccbfec40139322a28d77f61e45e
# Successfully built randomuser
# Installing collected packages: randomuser
# Successfully installed randomuser-1.6

# %% [markdown]
# ### 1) RandomUser API

# %%
from randomuser import RandomUser
import pandas as pd

# %%
r=RandomUser()
some_list=r.generate_users(10)
some_list
# Out:
# [<randomuser.RandomUser at 0x11a768350>,
#  <randomuser.RandomUser at 0x11a7a2b10>,
#  <randomuser.RandomUser at 0x11a76b150>,
#  <randomuser.RandomUser at 0x11a76bfd0>,
#  <randomuser.RandomUser at 0x11a76bc10>,
#  <randomuser.RandomUser at 0x11a76b890>,
#  <randomuser.RandomUser at 0x11a768e90>,
#  <randomuser.RandomUser at 0x11a76a550>,
#  <randomuser.RandomUser at 0x11a7980d0>,
#  <randomuser.RandomUser at 0x11a769150>]

# %% [markdown]
# ### Get Methods
#     get_cell()
#     get_city()
#     get_dob()
#     get_email()
#     get_first_name()
#     get_full_name()
#     get_gender()
#     get_id()
#     get_id_number()
#     get_id_type()
#     get_info()
#     get_last_name()
#     get_login_md5()
#     get_login_salt()
#     get_login_sha1()
#     get_login_sha256()
#     get_nat()
#     get_password()
#     get_phone()
#     get_picture()
#     get_postcode()
#     get_registered()
#     get_state()
#     get_street()
#     get_username()
#     get_zipcode()

# %%
#### We only need 10 users with full names and their email addresses
for user in some_list:
    print(user.get_full_name()," ",user.get_email())
# Out:
# Jar Ferguson   jar.ferguson@example.com
# Tatiana Rezende   tatiana.rezende@example.com
# Ceyhan Çevik   ceyhan.cevik@example.com
# Alfred Olsen   alfred.olsen@example.com
# Pinja Pesola   pinja.pesola@example.com
# Lya Marchand   lya.marchand@example.com
# Alexander Møller   alexander.moller@example.com
# Tércio da Cruz   tercio.dacruz@example.com
# Licelima Lima   licelima.lima@example.com
# Heinrich Nitschke   heinrich.nitschke@example.com

# %%
#### generate photos of the random 10 users.
for user in some_list:
    print(user.get_picture())
# Out:
# https://randomuser.me/api/portraits/men/73.jpg
# https://randomuser.me/api/portraits/women/54.jpg
# https://randomuser.me/api/portraits/women/37.jpg
# https://randomuser.me/api/portraits/men/14.jpg
# https://randomuser.me/api/portraits/women/16.jpg
# https://randomuser.me/api/portraits/women/4.jpg
# https://randomuser.me/api/portraits/men/76.jpg
# https://randomuser.me/api/portraits/men/27.jpg
# https://randomuser.me/api/portraits/women/91.jpg
# https://randomuser.me/api/portraits/men/50.jpg

# %% [markdown]
# To generate a table with information about the users, we can write a function containing all desirable parameters. For example, name, gender, city, etc. The parameters will depend on the requirements of the test to be performed. We call the Get Methods, listed at the beginning of this notebook. Then, we return pandas dataframe with the users.

# %%
def get_users():
    users=[]
    r=RandomUser()
    users1=r.generate_users(9)
    for user in users1:
        users.append({"Name":user.get_full_name(),
                      "Gender":user.get_gender(),
                      "City":user.get_city(),
                      "State":user.get_state(),
                      "Email":user.get_email(),
                      "DOB":user.get_dob(),
                      "Picture":user.get_picture()})
    return pd.DataFrame(users)

# %%
get_users()
# Out:
#               Name  Gender          City            State  \
# 0    کیانا محمدخان  female        شهریار            زنجان
# 1   Nalan Saygıner  female     Kastamonu          Bilecik
# 2    Adèle Riviere  female          Lyon            Paris
# 3   Molly Robinson  female      Hastings         Auckland
# 4      Pinja Korpi  female       Vihanti          Lapland
# 5  Kenneth Barrett    male  Jacksonville         Michigan
# 6     Dustin Miles    male     Devonport  South Australia
# 7     Amanda Saari  female       Kronoby     Ostrobothnia
# 8      Neea Rautio  female       Kempele     Ostrobothnia
#
#                          Email                       DOB  \
# 0     khyn.mhmdkhn@example.com  1947-08-18T19:39:37.554Z
# 1   nalan.sayginer@example.com  1984-03-25T09:08:11.463Z
# 2    adele.riviere@example.com  1986-02-05T16:56:45.518Z
# 3   molly.robinson@example.com  1984-06-01T12:32:26.930Z
# 4      pinja.korpi@example.com  1995-11-29T21:50:02.843Z
# 5  kenneth.barrett@example.com  1975-09-10T21:04:59.978Z
# 6     dustin.miles@example.com  1961-06-15T12:43:05.373Z
# 7     amanda.saari@example.com  1958-08-08T05:32:35.540Z
# 8      neea.rautio@example.com  1970-07-24T12:51:14.351Z
#
#                                             Picture
# 0  https://randomuser.me/api/portraits/women/71.jpg
# 1  https://randomuser.me/api/portraits/women/30.jpg
# 2  https://randomuser.me/api/portraits/women/59.jpg
# 3  https://randomuser.me/api/portraits/women/68.jpg
# 4  https://randomuser.me/api/portraits/women/38.jpg
# 5    https://randomuser.me/api/portraits/men/17.jpg
# 6    https://randomuser.me/api/portraits/men/16.jpg
# 7  https://randomuser.me/api/portraits/women/36.jpg
# 8  https://randomuser.me/api/portraits/women/36.jpg

# %% [markdown]
# ### Example 2: Fruityvice API

# %%
import requests
import json

# %%
data=requests.get("https://web.archive.org/web/20240929211114/https://fruityvice.com/api/fruit/all")
results=json.loads(data.text)

# %%
pd.DataFrame(results)
df=pd.json_normalize(results)
df
# Out:
#                   name   id           family             order         genus  \
# 0            Persimmon   52        Ebenaceae           Rosales     Diospyros
# 1           Strawberry    3         Rosaceae           Rosales      Fragaria
# 2               Banana    1         Musaceae      Zingiberales          Musa
# 3               Tomato    5       Solanaceae         Solanales       Solanum
# 4                 Pear    4         Rosaceae           Rosales         Pyrus
# 5               Durian   60        Malvaceae          Malvales         Durio
# 6           Blackberry   64         Rosaceae           Rosales         Rubus
# 7          Lingonberry   65        Ericaceae          Ericales     Vaccinium
# 8                 Kiwi   66    Actinidiaceae  Struthioniformes       Apteryx
# 9               Lychee   67      Sapindaceae        Sapindales        Litchi
# 10           Pineapple   10     Bromeliaceae            Poales        Ananas
# 11                 Fig   68         Moraceae           Rosales         Ficus
# 12          Gooseberry   69  Grossulariaceae      Saxifragales         Ribes
# 13        Passionfruit   70   Passifloraceae      Malpighiales    Passiflora
# 14                Plum   71         Rosaceae           Rosales        Prunus
# 15              Orange    2         Rutaceae        Sapindales        Citrus
# 16          GreenApple   72         Rosaceae           Rosales         Malus
# 17           Raspberry   23         Rosaceae           Rosales         Rubus
# 18          Watermelon   25    Cucurbitaceae      Cucurbitales     Citrullus
# 19               Lemon   26         Rutaceae        Sapindales        Citrus
# 20               Mango   27    Anacardiaceae        Sapindales     Mangifera
# 21           Blueberry   33         Rosaceae           Rosales      Fragaria
# 22               Apple    6         Rosaceae           Rosales         Malus
# 23               Guava   37        Myrtaceae          Myrtales       Psidium
# 24             Apricot   35         Rosaceae           Rosales        Prunus
# 25               Melon   41    Cucurbitaceae     Cucurbitaceae       Cucumis
# 26           Tangerine   77         Rutaceae        Sapindales        Citrus
# 27            Pitahaya   78        Cactaceae    Caryophyllales     Cactaceae
# 28                Lime   44         Rutaceae        Sapindales        Citrus
# 29         Pomegranate   79       Lythraceae          Myrtales        Punica
# 30         Dragonfruit   80        Cactaceae    Caryophyllales  Selenicereus
# 31               Grape   81         Vitaceae           Vitales         Vitis
# 32               Morus   82         Moraceae           Rosales         Morus
# 33              Feijoa   76        Myrtaceae        Myrtoideae    Sellowiana
# 34             Avocado   84        Lauraceae          Laurales        Persea
# 35           Kiwifruit   85    Actinidiaceae          Ericales     Actinidia
# 36           Cranberry   87        Ericaceae          Ericales     Vaccinium
# 37              Cherry    9         Rosaceae           Rosales        Prunus
# 38               Peach   86         Rosaceae           Rosales        Prunus
# 39           Jackfruit   94         Moraceae           Rosales    Artocarpus
# 40        Horned Melon   95    Cucurbitaceae      Cucurbitales       Cucumis
# 41            Hazelnut   96       Betulaceae           Fagales       Corylus
# 42              Pomelo   98         Rutaceae        Sapindales        Citrus
# 43          Mangosteen   99       Clusiaceae      Malpighiales      Garcinia
# 44             Pumpkin  100    Cucurbitaceae      Cucurbitales     Cucurbita
# 45  Japanese Persimmon  101        Ebenaceae          Ericales     Diospyros
# 46              Papaya   42       Caricaceae       Brassicales        Carica
# 47              Annona  103       Annonaceae           Rosales       Annonas
# 48   Ceylon Gooseberry  104       Salicaceae      Malpighiales      Dovyalis
#
#     nutritions.calories  nutritions.fat  nutritions.sugar  \
# 0                    81            0.00             18.00
# 1                    29            0.40              5.40
# 2                    96            0.20             17.20
# 3                    74            0.20              2.60
# 4                    57            0.10             10.00
# 5                   147            5.30              6.75
# 6                    40            0.40              4.50
# 7                    50            0.34              5.74
# 8                    61            0.50              9.00
# 9                    66            0.44             15.00
# 10                   50            0.12              9.85
# 11                   74            0.30             16.00
# 12                   44            0.60              0.00
# 13                   97            0.70             11.20
# 14                   46            0.28              9.92
# 15                   43            0.20              8.20
# 16                   21            0.10              6.40
# 17                   53            0.70              4.40
# 18                   30            0.20              6.00
# 19                   29            0.30              2.50
# 20                   60            0.38             13.70
# 21                   29            0.40              5.40
# 22                   52            0.40             10.30
# 23                   68            1.00              9.00
# 24                   15            0.10              3.20
# 25                   34            0.00              8.00
# 26                   45            0.40              9.10
# 27                   36            0.40              3.00
# 28                   25            0.10              1.70
# 29                   83            1.20             13.70
# 30                   60            1.50              8.00
# 31                   69            0.16             16.00
# 32                   43            0.39              8.10
# 33                   44            0.40              3.00
# 34                  160           14.66              0.66
# 35                   61            0.50              8.90
# 36                   46            0.10              4.00
# 37                   50            0.30              8.00
# 38                   39            0.25              8.40
# 39                   95            0.00             19.10
# 40                   44            1.26              0.50
# 41                  628           61.00              4.30
# 42                   37            0.00              8.50
# 43                   73            0.58             16.11
# 44                   25            0.30              3.30
# 45                   70            0.20             13.00
# 46                   39            0.30              4.40
# 47                   92            0.29              3.40
# 48                   47            0.30              8.10
#
#     nutritions.carbohydrates  nutritions.protein
# 0                      18.00                0.00
# 1                       5.50                0.80
# 2                      22.00                1.00
# 3                       3.90                0.90
# 4                      15.00                0.40
# 5                      27.10                1.50
# 6                       9.00                1.30
# 7                      11.30                0.75
# 8                      15.00                1.10
# 9                      17.00                0.80
# 10                     13.12                0.54
# 11                     19.00                0.80
# 12                     10.00                0.90
# 13                     22.40                2.20
# 14                     11.40                0.70
# 15                      8.30                1.00
# 16                      3.10                0.40
# 17                     12.00                1.20
# 18                      8.00                0.60
# 19                      9.00                1.10
# 20                     15.00                0.82
# 21                      5.50                0.00
# 22                     11.40                0.30
# 23                     14.00                2.60
# 24                      3.90                0.50
# 25                      8.00                0.00
# 26                      8.30                0.00
# 27                      7.00                1.00
# 28                      8.40                0.30
# 29                     18.70                1.70
# 30                      9.00                9.00
# 31                     18.10                0.72
# 32                      9.80                1.44
# 33                      8.00                0.60
# 34                      8.53                2.00
# 35                     14.60                1.14
# 36                     12.20                0.40
# 37                     12.00                1.00
# 38                      9.50                0.90
# 39                     23.20                1.72
# 40                      7.56                1.78
# 41                     17.00               15.00
# 42                      9.67                0.82
# 43                     17.91                0.41
# 44                      4.60                1.10
# 45                     19.00                0.60
# 46                      5.80                0.50
# 47                     19.10                1.50
# 48                      9.60                1.20

# %%
cal_banana=df.loc[df["name"]=="Banana"]
(cal_banana.iloc[0]["nutritions.calories"]),(cal_banana.iloc[0]["genus"])
# Out:
# (np.int64(96), 'Musa')

# %% [markdown]
# ### Official Joke API

# %%
import requests
data=requests.get("https://official-joke-api.appspot.com/jokes/ten")
retrieve=json.loads(data.text)
pd.DataFrame(retrieve)
df=pd.json_normalize(retrieve)

# %%
df
# Out:
#           type                                              setup  \
# 0      general               What did the ocean say to the shore?
# 1      general            What do you call a cow on a trampoline?
# 2  programming     Why did the functions stop calling each other?
# 3      general  Did you hear about the crime in the parking ga...
# 4      general  What do you call a troublesome Canadian high s...
# 5      general  What did the Buffalo say to his little boy whe...
# 6      general  Why did the worker get fired from the orange j...
# 7      general  What do you call an Argentinian with a rubber ...
# 8      general  What did the janitor say when he jumped out of...
# 9      general                 What's red and bad for your teeth?
#
#                               punchline   id
# 0               Nothing, it just waved.  179
# 1                         A milk shake!  195
# 2  Because they had constant arguments.  406
# 3       It was wrong on so many levels.  394
# 4                            A poutine.  216
# 5                                Bison.  168
# 6                Lack of concentration.  336
# 7                               Roberto  218
# 8                             Supplies!  424
# 9                              A Brick.  268
