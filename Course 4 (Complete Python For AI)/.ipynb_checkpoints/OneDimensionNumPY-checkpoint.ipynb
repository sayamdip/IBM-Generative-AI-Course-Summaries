# %% [markdown]
# ### One Dimensional NumPy

# %%
import numpy as np
a=np.array([0,1,2,3,4])
print(type(a))
# Out:
# <class 'numpy.ndarray'>

# %% [markdown]
# ### Find The Data Type Of Elements

# %%
print(a.dtype)
# Out:
# int64

# %% [markdown]
# ### Basic Array Attributes

# %%
print(a.size)
# Out:
# 5

# %%
b=np.array([3.1,11.02,6.2,213,5.2])
print(type(b))
print(b.dtype)
# Out:
# <class 'numpy.ndarray'>
# float64

# %%
b[0]=100
print(b)
# Out:
# [100.    11.02   6.2  213.     5.2 ]

# %%
print(b[1:4])
# Out:
# [ 11.02   6.2  213.  ]

# %%
b[3:5]=300,400
print(b)
# Out:
# [100.    11.02   6.2  300.   400.  ]

# %% [markdown]
# ### Get The Number Of Dimensions Of numpy Array

# %%
print(b.ndim)
# Out:
# 1

# %% [markdown]
# ### Vector Addition And Vector Substraction

# %%
u=np.array([4,5])
v=np.array([5,4])
z=u+v
m=u-v
print("Addition=",z)
print("Substraction=",m)
# Out:
# Addition= [9 9]
# Substraction= [-1  1]

# %% [markdown]
# ### Array Multiplication

# %%
p=2*u
print(p)
# Out:
# [ 8 10]

# %% [markdown]
# ### Product Of Two Numpy Arrays

# %%
z=u*v
print("Multiplication=",z)
# Out:
# Multiplication= [20 20]

# %% [markdown]
# ### Dot Products Of Two Matrix

# %%
result=np.dot(u,v)
print(result)
# Out:
# 40

# %% [markdown]
# ### Mean Values Of An Array

# %%
mean_b=b.mean()
print(mean_b)
# Out:
# 163.44400000000002

# %% [markdown]
# ### Max Value Of An Array

# %%
max_b=b.max()
print(max_b)
# Out:
# 400.0

# %%
pi=np.pi
array=np.array([0,pi/2,pi])
print(array)
# Out:
# [0.         1.57079633 3.14159265]

# %% [markdown]
# ### Applying sin Function To the Array

# %%
print(np.sin(array))
# Out:
# [0.0000000e+00 1.0000000e+00 1.2246468e-16]

# %% [markdown]
# ### linspace

# %%
print(np.linspace(-2,2,num=9))
# Out:
# [-2.  -1.5 -1.  -0.5  0.   0.5  1.   1.5  2. ]

# %%
array2=np.linspace(0,2*pi,100)
print(array2)
# Out:
# [0.         0.06346652 0.12693304 0.19039955 0.25386607 0.31733259
#  0.38079911 0.44426563 0.50773215 0.57119866 0.63466518 0.6981317
#  0.76159822 0.82506474 0.88853126 0.95199777 1.01546429 1.07893081
#  1.14239733 1.20586385 1.26933037 1.33279688 1.3962634  1.45972992
#  1.52319644 1.58666296 1.65012947 1.71359599 1.77706251 1.84052903
#  1.90399555 1.96746207 2.03092858 2.0943951  2.15786162 2.22132814
#  2.28479466 2.34826118 2.41172769 2.47519421 2.53866073 2.60212725
#  2.66559377 2.72906028 2.7925268  2.85599332 2.91945984 2.98292636
#  3.04639288 3.10985939 3.17332591 3.23679243 3.30025895 3.36372547
#  3.42719199 3.4906585  3.55412502 3.61759154 3.68105806 3.74452458
#  3.8079911  3.87145761 3.93492413 3.99839065 4.06185717 4.12532369
#  4.1887902  4.25225672 4.31572324 4.37918976 4.44265628 4.5061228
#  4.56958931 4.63305583 4.69652235 4.75998887 4.82345539 4.88692191
#  4.95038842 5.01385494 5.07732146 5.14078798 5.2042545  5.26772102
# ...

# %%
y=np.sin(array2)

# %%
import matplotlib.pyplot as plt
plt.plot(array2,y)

# %%
print(np.__version__)
# Out:
# 2.4.4

# %%
arr1 = np.array([10, 11, 12, 13, 14, 15])
arr2 = np.array([20, 21, 22, 23, 24, 25])

# Addition
print("Addition=",np.add(arr1,arr2))

# Substraction
print("Subtraction=",np.subtract(arr1,arr2))

# Multiplication
print("Multiplication=",np.multiply(arr1,arr2))

# Division
print("Division=",np.divide(arr1,arr2))

# Dot Product
print("Dot Product=",np.dot(arr1,arr2))
# Out:
# Addition= [30 32 34 36 38 40]
# Subtraction= [-10 -10 -10 -10 -10 -10]
# Multiplication= [200 231 264 299 336 375]
# Division= [0.5        0.52380952 0.54545455 0.56521739 0.58333333 0.6       ]
# Dot Product= 1705

# %%
import matplotlib.pyplot as plt
a=np.array([-1,1])
b=np.array([1,1])
plt.plot(a,b)

# %%
a=np.array([-1,1])
b=np.array([1,1])
print(np.dot(a,b))
# Out:
# 0
